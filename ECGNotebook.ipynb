# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
from torchvision import transforms, datasets
from torchmetrics import Accuracy

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from .. import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [10], in <cell line: 12>()
#       9 import numpy as np
#      10 import matplotlib.pyplot as plt
# ---> 12 from .. import *
#
# ImportError: attempted relative import with no known parent package

# %%
CustomDTS("../datasets/ECG200_TRAIN.txt")

# %%
X = []
Y = []
for line in file.readlines():
    Y.append([float(i) for i in line.split()][0])
    X.append([float(i) for i in line.split()][1:])

X = np.array(X, dtype='float32')
Y = np.array(Y, dtype='int8')

# %%
print(Y[0])
print(X[0])
# Out:
# -1
# [ 0.50205547  0.54216266  0.7223835   1.4288852   2.1365159   2.281149
#   1.9362737   1.46889     1.0088451   0.38028225 -0.29677966 -0.51392865
#  -0.25564468 -0.10720254 -0.28782654 -0.418009   -0.31916314 -0.2603787
#  -0.3503572  -0.505486   -0.7108871  -0.82391983 -0.89970154 -1.1539497
#  -1.2298306  -1.044091   -1.2020313  -1.3921949  -1.1301084  -1.1798666
#  -1.6492718  -1.7265754  -1.6083704  -1.6628022  -1.6506724  -1.6973094
#  -1.8386968  -1.8025962  -1.780536   -1.8251665  -1.6447634  -1.4238096
#  -1.3921949  -1.3604156  -1.2001781  -0.9186323  -0.6859158  -0.6679435
#  -0.51272154 -0.10169069  0.06395426  0.08261431  0.23760718  0.17479318
#   0.12320539  0.5033942   0.6838702   0.47499475  0.5327971   0.72354996
#   0.6644198   0.64793557  0.75705403  0.7320716   0.620215    0.6062968
#   0.67795014  0.68908364  0.5988073   0.5426466   0.5818074   0.6306307
#   0.6644198   0.6863178   0.6573825   0.65088946  0.7217384   0.73970646
#   0.6914805   0.6952295   0.7501145   0.8538448   0.9160189   0.82774967
#   0.88090557  1.0888307   0.93104297  0.61029834  0.63889426  0.68467855
#   0.58323765  0.64052165  0.70858514  0.7050109   0.71381545  0.43376464]

# %%
index = 1
print(Y[index])
plt.plot([i for i in range(len(X[index]))], X[index])
plt.show()
# Out:
# 1

# %%
index = 2
print(Y[index])
plt.plot([i for i in range(len(X[index]))], X[index])
plt.show()
# Out:
# -1
